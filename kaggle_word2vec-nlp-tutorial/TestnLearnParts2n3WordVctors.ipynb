# %%
import pandas as pd

# Read data from files 
train = pd.read_csv( "labeledTrainData.tsv", header=0, 
 delimiter="\t", quoting=3 )
test = pd.read_csv( "testData.tsv", header=0, delimiter="\t", quoting=3 )
unlabeled_train = pd.read_csv( "unlabeledTrainData.tsv", header=0, 
 delimiter="\t", quoting=3 )

# %%
import gensim
all_stopwords = gensim.parsing.preprocessing.STOPWORDS
print(all_stopwords)
# Out:
# frozenset({'us', 'am', 'km', 'see', 'above', 'again', 'or', 'himself', 'name', 'system', 'the', 'twenty', 'you', 'well', 'keep', 'take', 'least', 'these', 'twelve', 'hundred', 'empty', 'off', 'mine', 'beside', 'can', 'out', 'side', 'themselves', 'whole', 'somehow', 'already', 'up', 'their', 'thence', 'beyond', 'thus', 'are', 'bottom', 'cry', 'eg', 'ltd', 'them', 'seeming', 'among', 'which', 'latterly', 'inc', 'onto', 'eight', 'whom', 'make', 'throughout', 'hence', 'each', 'whenever', 'fifty', 'become', 'along', 'however', 'part', 'nowhere', 'around', 'using', 'describe', 'from', 'do', 'it', 'being', 'many', 'anyhow', 'with', 'back', 'became', 'hasnt', 'him', 'none', 'forty', 'and', 'eleven', 'afterwards', 'has', 'hereupon', 'of', 'an', 'wherein', 'had', 'more', 'further', 'on', 'is', 'didn', 'at', 'through', 'ie', 'hers', 'etc', 'against', 'between', 'not', 'together', 'its', 'still', 'yourselves', 'always', 'as', 'whither', 'about', 'de', 'have', 'next', 'seems', 'everyone', 'full', 'bill', 'only', 'she', 'never', 'anyone', 'give', 'four', 're', 'all', 'yourself', 'wherever', 'becoming', 'less', 'herself', 'was', 'really', 'seem', 'yours', 'may', 'whereafter', 'ten', 'meanwhile', 'move', 'sixty', 'he', 'under', 'although', 'myself', 'toward', 'they', 'show', 'whereas', 'my', 'first', 'be', 'say', 'for', 'even', 'beforehand', 'someone', 'thereby', 'if', 'could', 'must', 'hereafter', 'seemed', 'couldnt', 'because', 'since', 'unless', 'now', 'latter', 'but', 'whoever', 'either', 'thick', 'that', 'those', 'few', 'find', 'no', 'there', 'within', 'thereafter', 'over', 'via', 'noone', 'some', 'go', 'where', 'call', 'doesn', 'fifteen', 'her', 'six', 'to', 'elsewhere', 'fire', 'mill', 'most', 'therein', 'nothing', 'five', 'else', 'would', 'something', 'cant', 'yet', 'neither', 'so', 'then', 'whereupon', 'been', 'often', 'formerly', 'into', 'except', 'put', 'two', 'computer', 'un', 'front', 'herein', 'nobody', 'alone', 'everywhere', 'kg', 'due', 'amongst', 'thru', 'any', 'doing', 'besides', 'sometimes', 'in', 'without', 'we', 'quite', 'during', 'serious', 'others', 'me', 'our', 'down', 'nor', 'here', 'ours', 'made', 'ourselves', 'whereby', 'get', 'nevertheless', 'this', 'across', 'otherwise', 'namely', 'three', 'please', 'don', 'while', 'thin', 'when', 'once', 'sincere', 'behind', 'his', 'somewhere', 'therefore', 'just', 'con', 'almost', 'upon', 'why', 'whether', 'rather', 'after', 'detail', 'too', 'becomes', 'such', 'own', 'a', 'former', 'will', 'every', 'by', 'third', 'regarding', 'same', 'other', 'towards', 'used', 'found', 'indeed', 'did', 'several', 'what', 'does', 'were', 'perhaps', 'hereby', 'anyway', 'itself', 'before', 'amoungst', 'both', 'enough', 'whatever', 'last', 'co', 'thereupon', 'various', 'ever', 'moreover', 'per', 'everything', 'sometime', 'amount', 'one', 'mostly', 'below', 'anywhere', 'i', 'also', 'your', 'anything', 'should', 'might', 'very', 'much', 'though', 'cannot', 'another', 'than', 'whence', 'until', 'whose', 'top', 'how', 'who', 'fill', 'interest', 'done', 'nine'})

# %%
# Verify the number of reviews that were read (100,000 in total)
haha = train["review"].size; hihi = test["review"].size
hoho = unlabeled_train["review"].size
print(f"Read {haha} labeled train reviews, {hihi} labeled test reviews, and {hoho} unlabeled reviews\n")
#print(f"Read {train["review"].size} labeled train reviews, {hihi} labeled test reviews, and {hoho} unlabeled reviews\n")
# Out:
# Read 25000 labeled train reviews, 25000 labeled test reviews, and 50000 unlabeled reviews

# %%
# Import various modules for string cleaning
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

def review_to_wordlist( review, remove_stopwords=False ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(review).get_text()
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review_text)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# %%
# Download the punkt tokenizer for sentence splitting
import nltk.data
#No need to run the below line again after it has been run 
#nltk.download()
nltk.download('punkt')
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Eric\anaconda3\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Define a function to split a review into parsed sentences
def review_to_sentences( review, tokenizer, remove_stopwords=False ):
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence, \
              remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
sentences = []  # Initialize an empty list of sentences

print("Parsing sentences from training set")
for review in train["review"]:
    sentences += review_to_sentences(review, tokenizer)

print("Parsing sentences from unlabeled set")
for review in unlabeled_train["review"]:
    sentences += review_to_sentences(review, tokenizer)
# Out:
# Parsing sentences from training set
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:329: MarkupResemblesLocatorWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:329: MarkupResemblesLocatorWarning: "..." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "http://www.happierabroad.com"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# Parsing sentences from unlabeled set
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "http://www.archive.org/details/LovefromaStranger"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "http://www.loosechangeguide.com/LooseChangeGuide.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:329: MarkupResemblesLocatorWarning: "... ..." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:329: MarkupResemblesLocatorWarning: "...." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "http://www.msnbc.msn.com/id/4972055/site/newsweek/"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:329: MarkupResemblesLocatorWarning: ".." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "http://www.youtube.com/watch?v=a0KSqelmgN8"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:329: MarkupResemblesLocatorWarning: ".. ." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Eric\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "http://jake-weird.blogspot.com/2007/08/beneath.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
print(len(sentences))
# Out:
# 795538

# %%
print(sentences[0])
# Out:
# ['with', 'all', 'this', 'stuff', 'going', 'down', 'at', 'the', 'moment', 'with', 'mj', 'i', 've', 'started', 'listening', 'to', 'his', 'music', 'watching', 'the', 'odd', 'documentary', 'here', 'and', 'there', 'watched', 'the', 'wiz', 'and', 'watched', 'moonwalker', 'again']

# %%
print(sentences[1])
# Out:
# ['maybe', 'i', 'just', 'want', 'to', 'get', 'a', 'certain', 'insight', 'into', 'this', 'guy', 'who', 'i', 'thought', 'was', 'really', 'cool', 'in', 'the', 'eighties', 'just', 'to', 'maybe', 'make', 'up', 'my', 'mind', 'whether', 'he', 'is', 'guilty', 'or', 'innocent']

# %%
# Import the built-in logging module and configure it so that Word2Vec 
# creates nice output messages
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print("Training model...")
model = word2vec.Word2Vec(sentences, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)

# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
model_name = "300features_40minwords_10context"
model.save(model_name)
# Out:
# 2020-08-17 12:22:56,266 : INFO : collecting all words and their counts
# 2020-08-17 12:22:56,267 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-08-17 12:22:56,315 : INFO : PROGRESS: at sentence #10000, processed 225803 words, keeping 17776 word types
# 2020-08-17 12:22:56,360 : INFO : PROGRESS: at sentence #20000, processed 451892 words, keeping 24948 word types
# 2020-08-17 12:22:56,400 : INFO : PROGRESS: at sentence #30000, processed 671315 words, keeping 30034 word types
# 2020-08-17 12:22:56,445 : INFO : PROGRESS: at sentence #40000, processed 897815 words, keeping 34348 word types
# Training model...
# 2020-08-17 12:22:56,493 : INFO : PROGRESS: at sentence #50000, processed 1116963 words, keeping 37761 word types
# 2020-08-17 12:22:56,538 : INFO : PROGRESS: at sentence #60000, processed 1338404 words, keeping 40723 word types
# 2020-08-17 12:22:56,583 : INFO : PROGRESS: at sentence #70000, processed 1561580 words, keeping 43333 word types
# 2020-08-17 12:22:56,629 : INFO : PROGRESS: at sentence #80000, processed 1780887 words, keeping 45714 word types
# 2020-08-17 12:22:56,676 : INFO : PROGRESS: at sentence #90000, processed 2004996 words, keeping 48135 word types
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-08-17 12:24:04,809 : INFO : EPOCH - 5 : training on 17798082 raw words (12749713 effective words) took 13.2s, 965676 effective words/s
# 2020-08-17 12:24:04,810 : INFO : training on a 88990410 raw words (63744822 effective words) took 61.9s, 1030406 effective words/s
# 2020-08-17 12:24:04,810 : INFO : precomputing L2-norms of word weight vectors
# 2020-08-17 12:24:04,827 : INFO : saving Word2Vec object under 300features_40minwords_10context, separately None
# 2020-08-17 12:24:04,828 : INFO : not storing attribute vectors_norm
# 2020-08-17 12:24:04,829 : INFO : not storing attribute cum_table
# 2020-08-17 12:24:08,068 : INFO : saved 300features_40minwords_10context

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# <ipython-input-21-c4c7e8da36b4>:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   model.doesnt_match("man woman child kitchen".split())
# C:\Users\Eric\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'kitchen'

# %%
model.doesnt_match("paris berlin london austria".split())
# Out:
# <ipython-input-22-45844e2ac28d>:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   model.doesnt_match("paris berlin london austria".split())
# 'paris'

# %%
model.most_similar("man")
# Out:
# <ipython-input-25-216414787a03>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("man")
# [('woman', 0.6274001598358154),
#  ('lady', 0.58546382188797),
#  ('lad', 0.5497606992721558),
#  ('chap', 0.5246933698654175),
#  ('men', 0.5151287317276001),
#  ('farmer', 0.5089752078056335),
#  ('millionaire', 0.504858136177063),
#  ('guy', 0.5045832395553589),
#  ('person', 0.5030724406242371),
#  ('monk', 0.49608126282691956)]

# %%
model.most_similar("asian")
# Out:
# <ipython-input-26-631ed7059b1a>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("asian")
# [('hispanic', 0.6373258829116821),
#  ('italian', 0.6330246329307556),
#  ('indian', 0.617671012878418),
#  ('japanese', 0.6164621114730835),
#  ('chinese', 0.6158310770988464),
#  ('european', 0.5787085890769958),
#  ('oriental', 0.5749025940895081),
#  ('themed', 0.5745910406112671),
#  ('korean', 0.5658513307571411),
#  ('african', 0.5605590343475342)]

# %%
model.most_similar("awful")
# Out:
# <ipython-input-27-efd9e43fbdfc>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("awful")
# [('terrible', 0.7750945091247559),
#  ('atrocious', 0.7391469478607178),
#  ('horrible', 0.7196462154388428),
#  ('dreadful', 0.7093713283538818),
#  ('abysmal', 0.707600474357605),
#  ('horrendous', 0.6793471574783325),
#  ('horrid', 0.6754946708679199),
#  ('appalling', 0.6526410579681396),
#  ('lousy', 0.6385699510574341),
#  ('bad', 0.594570517539978)]

# %%
haha = model.wv['awful']
haha, haha.size
# Out:
# (array([-0.00894489,  0.09097632,  0.08290248, -0.06561998,  0.10963804,
#         -0.08678921, -0.04285555, -0.05159815, -0.04258895,  0.01402137,
#         -0.09597661, -0.00079995,  0.05948284,  0.10495246,  0.03852861,
#         -0.03857021, -0.07710546,  0.01235159, -0.02138139,  0.067014  ,
#         -0.09048748,  0.00313454, -0.0829851 ,  0.05205329, -0.03562295,
#         -0.02628679,  0.0661581 , -0.11699639, -0.07002712,  0.08033858,
#         -0.00142982, -0.03062679, -0.05699936, -0.0171799 , -0.03983486,
#          0.0024056 ,  0.00756572, -0.01305054, -0.05922726,  0.01681226,
#         -0.00441556,  0.03953473, -0.02105783,  0.03417582,  0.0341506 ,
#         -0.02173842,  0.07524794, -0.01364917, -0.07290785, -0.08778565,
#         -0.02578782,  0.04638334,  0.13097678, -0.02744051, -0.0751076 ,
#          0.08903234,  0.10497618, -0.09583668,  0.04383833,  0.0031541 ,
#         -0.03227499, -0.00767971,  0.0615964 , -0.11248825,  0.05906817,
#         -0.03751199,  0.0665074 ,  0.04965273, -0.05409756,  0.05747773,
#          0.07898006,  0.0110235 ,  0.10097706,  0.010776  ,  0.05413346,
#          0.03316856, -0.0643665 , -0.03901769,  0.00513315, -0.01849724,
#          0.0457753 ,  0.09928359, -0.03457375, -0.05132502, -0.01571015,
#         -0.13314283, -0.03147844,  0.07533573,  0.01535466,  0.13644019,
#          0.05601867,  0.01514968,  0.00538271, -0.04875567,  0.01835858],
#        dtype=float32),
#  300)

# %%
#part 3 started here
#changes below were made according to 
#https://groups.google.com/g/gensim/c/hlYgjqEVocw
#some methods and attributes were moved to
#KeyedVectors class from word2vec class
from gensim.models import Word2Vec, KeyedVectors

# %%
model = KeyedVectors.load("300features_40minwords_10context")
# Out:
# 2020-08-17 12:39:51,052 : INFO : loading Word2VecKeyedVectors object from 300features_40minwords_10context
# 2020-08-17 12:39:51,321 : INFO : loading wv recursively from 300features_40minwords_10context.wv.* with mmap=None
# 2020-08-17 12:39:51,322 : INFO : setting ignored attribute vectors_norm to None
# 2020-08-17 12:39:51,322 : INFO : loading vocabulary recursively from 300features_40minwords_10context.vocabulary.* with mmap=None
# 2020-08-17 12:39:51,323 : INFO : loading trainables recursively from 300features_40minwords_10context.trainables.* with mmap=None
# 2020-08-17 12:39:51,324 : INFO : setting ignored attribute cum_table to None
# 2020-08-17 12:39:51,324 : INFO : loaded 300features_40minwords_10context

# %%
#changed: wv. added
type(model.wv.syn0)
# Out:
# <ipython-input-40-04073011a372>:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   type(model.wv.syn0)
# numpy.ndarray

# %%
model.wv.syn0.shape
# Out:
# <ipython-input-41-b77a3a51ff8b>:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   model.wv.syn0.shape
# (16490, 300)

# %% [raw]
# model.wv['flower']

# %%
#be careful: nword and counter must be integers --Chiu
import numpy as np  # Make sure that numpy is imported

def makeFeatureVec(words, model, num_features):
    # Function to average all of the word vectors in a given
    # paragraph
    #
    # Pre-initialize an empty numpy array (for speed)
    featureVec = np.zeros((num_features,),dtype="float32")
    #
    nwords = 0
    # 
    # Index2word is a list that contains the names of the words in 
    # the model's vocabulary. Convert it to a set, for speed 
    index2word_set = set(model.wv.index2word)
    #
    # Loop over each word in the review and, if it is in the model's
    # vocaublary, add its feature vector to the total
    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1
            featureVec = np.add(featureVec,model[word])
    # 
    # Divide the result by the number of words to get the average
    featureVec = np.divide(featureVec,nwords)
    return featureVec


def getAvgFeatureVecs(reviews, model, num_features):
    # Given a set of reviews (each one a list of words), calculate 
    # the average feature vector for each one and return a 2D numpy array 
    # 
    # Initialize a counter
    counter = 0
    # 
    # Preallocate a 2D numpy array, for speed
    reviewFeatureVecs = np.zeros((len(reviews),num_features),dtype="float32")
    # 
    # Loop through the reviews
    for review in reviews:
       #
       # Print a status message every 1000th review
        if counter%1000 == 0:
            haha = counter; hihi = len(reviews)
            print(f"Review {haha} of {hihi}") #% (counter, len(reviews))
       # 
       # Call the function (defined above) that makes average feature vectors
        #reviewFeatureVecs[counter] = makeFeatureVec(review, model, num_features)
        reviewFeatureVecs[counter] = makeFeatureVec(review, model, num_features)
       #
       # Increment the counter
        counter = counter + 1
    return reviewFeatureVecs

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
type(model)
# Out:
# gensim.models.word2vec.Word2Vec

# %%
# ****************************************************************
# Calculate average feature vectors for training and testing sets,
# using the functions we defined above. Notice that we now use stop word
# removal.

clean_train_reviews = []
for review in train["review"]:
    clean_train_reviews.append( review_to_wordlist( review, \
        remove_stopwords=True ))

trainDataVecs = getAvgFeatureVecs( clean_train_reviews, model, num_features )

print("Creating average feature vecs for test reviews")
clean_test_reviews = []
for review in test["review"]:
    clean_test_reviews.append( review_to_wordlist( review, remove_stopwords=True ))

testDataVecs = getAvgFeatureVecs( clean_test_reviews, model, num_features )
# Out:
# Review 0 of 25000
# <ipython-input-47-779435e8b62e>:22: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   featureVec = np.add(featureVec,model[word])
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# Creating average feature vecs for test reviews
# Review 0 of 25000
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000

# %%
# Fit a random forest to the training data, using 100 trees
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier( n_estimators = 100 )

print("Fitting a random forest to labeled training data...")
forest = forest.fit( trainDataVecs, train["sentiment"] )

# Test & extract results 
result = forest.predict( testDataVecs )

# Write the test results 
output = pd.DataFrame( data={"id":test["id"], "sentiment":result} )
output.to_csv( "Word2Vec_AverageVectors.csv", index=False, quoting=3 )
# Out:
# Fitting a random forest to labeled training data...

# %%
print(output)
# Out:
#                id  sentiment
# 0      "12311_10"          1
# 1        "8348_2"          0
# 2        "5828_4"          1
# 3        "7186_2"          0
# 4       "12128_7"          1
# ...           ...        ...
# 24995   "2155_10"          1
# 24996     "59_10"          1
# 24997    "2531_1"          1
# 24998    "7772_8"          1
# 24999  "11465_10"          0
#
# [25000 rows x 2 columns]

# %%
# This cell takes 24 minutes in my asus vivobook s s510u 24g ram
from sklearn.cluster import KMeans
import time

start = time.time() # Start time

# Set "k" (num_clusters) to be 1/5th of the vocabulary size, or an
# average of 5 words per cluster
word_vectors = model.wv.syn0
num_clusters = word_vectors.shape[0] / 5

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = int(num_clusters) )
idx = kmeans_clustering.fit_predict( word_vectors )

# Get the end time and print how long the process took
end = time.time()
elapsed = end - start
print("Time taken for K Means clustering: ", elapsed, "seconds.")
# Out:
# <ipython-input-51-c310dcc16c02>:8: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   word_vectors = model.wv.syn0
# Time taken for K Means clustering:  1416.714765548706 seconds.

# %%
# Create a Word / Index dictionary, mapping each vocabulary word to
# a cluster number                                                                                            
word_centroid_map = dict(zip( model.wv.index2word, idx ))

# %%
word_centroid_map, len(word_centroid_map.keys()),
# Out:
# ({'the': 1832,
#   'and': 2241,
#   'a': 2485,
#   'of': 2078,
#   'to': 3043,
#   'is': 1335,
#   'it': 607,
#   'in': 2453,
#   'i': 1086,
#   'this': 607,
#   'that': 2341,
#   's': 1335,
#   'was': 2578,
#   'as': 3007,
#   'with': 2281,
#   'for': 1678,
#   'movie': 1185,
#   'but': 1257,
#   'film': 1185,
#   'you': 955,
#   't': 2313,
#   'on': 1143,
#   'not': 1253,
#   'he': 899,
#   'are': 3266,
#   'his': 1969,
#   'have': 902,
#   'be': 2399,
#   'one': 1584,
#   'all': 2998,
#   'at': 2799,
#   'they': 2628,
#   'by': 1957,
#   'who': 1450,
#   'an': 1429,
#   'from': 2343,
#   'so': 941,
#   'like': 2840,
#   'there': 1419,
#   'her': 2422,
#   'or': 2404,
#   'just': 2790,
#   'about': 2793,
#   'out': 615,
#   'has': 1044,
#   'if': 1014,
#   'what': 190,
#   'some': 446,
#   'good': 774,
#   'can': 496,
#   'more': 965,
#   'when': 1555,
#   'very': 1889,
#   'she': 899,
#   'up': 1051,
#   'no': 337,
#   'time': 3132,
#   'even': 2003,
#   'would': 789,
#   'my': 1378,
#   'which': 2341,
#   'their': 1899,
#   'story': 860,
#   'only': 1917,
#   'really': 321,
#   'see': 1505,
#   'had': 902,
#   'were': 3266,
#   'well': 604,
#   'we': 2628,
#   'me': 1086,
#   'than': 2380,
#   'much': 1113,
#   'bad': 2873,
#   'get': 837,
#   'been': 811,
#   'people': 1256,
#   'also': 2891,
#   'into': 1392,
#   'do': 2075,
#   'great': 1777,
#   'other': 1048,
#   'will': 135,
#   'first': 502,
#   'because': 1013,
#   'him': 899,
#   'how': 190,
#   'most': 2418,
#   'don': 76,
#   'them': 1899,
#   'made': 1517,
#   'its': 2144,
#   'make': 2128,
#   'then': 2408,
#   'way': 729,
#   'could': 789,
#   'too': 941,
#   'movies': 1116,
#   'after': 568,
#   'any': 337,
#   'characters': 719,
#   'character': 719,
#   'think': 1674,
#   'films': 1116,
#   'two': 2905,
#   'watch': 1505,
#   'being': 2766,
#   'many': 305,
#   'plot': 463,
#   'seen': 124,
#   'never': 1893,
#   'where': 1555,
#   'love': 3098,
#   'life': 2665,
#   'little': 3153,
#   'acting': 2580,
#   'best': 365,
#   'did': 1942,
#   'over': 2255,
#   'off': 615,
#   'know': 865,
#   'show': 2706,
#   'ever': 2119,
#   'does': 1942,
#   'man': 1547,
#   'better': 1126,
#   'your': 577,
#   'here': 1751,
#   'end': 1947,
#   'scene': 1491,
#   'these': 1471,
#   'still': 1504,
#   'while': 1557,
#   'why': 190,
#   'scenes': 1025,
#   'say': 1674,
#   'something': 1030,
#   'go': 837,
#   've': 902,
#   'm': 1388,
#   'should': 789,
#   'such': 1665,
#   'back': 1730,
#   'through': 266,
#   'real': 2889,
#   'those': 1471,
#   'now': 3212,
#   're': 1541,
#   'watching': 613,
#   'doesn': 76,
#   'thing': 2867,
#   'though': 841,
#   'director': 2877,
#   'years': 1418,
#   'actors': 1885,
#   'funny': 1407,
#   'old': 1366,
#   'didn': 76,
#   'another': 2485,
#   'new': 1582,
#   'nothing': 1030,
#   'makes': 3173,
#   'work': 2178,
#   'actually': 321,
#   'going': 2264,
#   'before': 568,
#   'look': 3060,
#   'find': 1505,
#   'same': 1816,
#   'lot': 3081,
#   'few': 305,
#   'part': 1702,
#   'every': 2690,
#   'again': 1991,
#   'world': 3140,
#   'cast': 2863,
#   'us': 1604,
#   'things': 2543,
#   'horror': 1668,
#   'quite': 2599,
#   'want': 1057,
#   'action': 1721,
#   'down': 540,
#   'pretty': 2599,
#   'young': 1340,
#   'around': 266,
#   'seems': 220,
#   'fact': 2006,
#   'take': 1310,
#   'however': 1257,
#   'enough': 2272,
#   'got': 1988,
#   'long': 2137,
#   'both': 3253,
#   'thought': 1462,
#   'big': 859,
#   'own': 3016,
#   'give': 293,
#   'between': 2493,
#   'd': 789,
#   'comedy': 484,
#   'series': 988,
#   'must': 789,
#   'may': 135,
#   'right': 1782,
#   'original': 1435,
#   'without': 977,
#   'role': 623,
#   'interesting': 543,
#   'come': 1988,
#   'times': 2222,
#   'always': 612,
#   'isn': 367,
#   'guy': 2126,
#   'saw': 1331,
#   'whole': 665,
#   'gets': 1552,
#   'least': 1542,
#   'point': 1949,
#   'almost': 2271,
#   'bit': 694,
#   'script': 3047,
#   'music': 2830,
#   'done': 861,
#   'last': 502,
#   'minutes': 444,
#   'far': 1113,
#   'family': 2421,
#   'feel': 1851,
#   'since': 1013,
#   'making': 1517,
#   'll': 135,
#   'girl': 449,
#   'might': 789,
#   'performance': 2580,
#   'anything': 1030,
#   'yet': 2091,
#   'away': 1734,
#   'probably': 2058,
#   'am': 1388,
#   'woman': 1547,
#   'tv': 127,
#   'kind': 532,
#   'hard': 975,
#   'fun': 736,
#   'rather': 34,
#   'day': 551,
#   'worst': 2418,
#   'sure': 1284,
#   'played': 2384,
#   'anyone': 1641,
#   'each': 2157,
#   'found': 2780,
#   'especially': 987,
#   'having': 2530,
#   'our': 1562,
#   'trying': 1177,
#   'screen': 1180,
#   'looking': 3060,
#   'believe': 1674,
#   'different': 3234,
#   'although': 1257,
#   'place': 313,
#   'course': 2153,
#   'goes': 1323,
#   'sense': 586,
#   'set': 14,
#   'comes': 1988,
#   'ending': 461,
#   'maybe': 2058,
#   'shows': 1624,
#   'worth': 1595,
#   'american': 396,
#   'three': 2905,
#   'dvd': 1045,
#   'money': 2037,
#   'put': 490,
#   'looks': 2782,
#   'once': 2719,
#   'everything': 190,
#   'actor': 1520,
#   'someone': 498,
#   'let': 1693,
#   'plays': 2384,
#   'effects': 3093,
#   'main': 1989,
#   'john': 808,
#   'wasn': 367,
#   'year': 594,
#   'together': 1269,
#   'reason': 1538,
#   'book': 1435,
#   'true': 1746,
#   'everyone': 1641,
#   'during': 1178,
#   'instead': 1347,
#   'takes': 3017,
#   'said': 1205,
#   'job': 636,
#   'high': 816,
#   'play': 1757,
#   'special': 852,
#   'war': 657,
#   'seem': 220,
#   'night': 551,
#   'watched': 1331,
#   'later': 739,
#   'audience': 1604,
#   'wife': 538,
#   'himself': 899,
#   'star': 3051,
#   'black': 1237,
#   'half': 2893,
#   'seeing': 613,
#   'left': 1041,
#   'death': 288,
#   'idea': 1214,
#   'excellent': 1777,
#   'beautiful': 1938,
#   'shot': 1010,
#   'house': 1455,
#   'second': 957,
#   'father': 1394,
#   'simply': 2790,
#   'used': 1920,
#   'men': 1293,
#   'dead': 2925,
#   'else': 1926,
#   'mind': 2665,
#   'version': 52,
#   'less': 34,
#   'completely': 827,
#   'hollywood': 1940,
#   'nice': 1026,
#   'poor': 2873,
#   'fan': 1964,
#   'budget': 993,
#   'women': 1293,
#   'help': 3071,
#   'home': 1919,
#   'line': 1750,
#   'sex': 1853,
#   'boring': 1120,
#   'performances': 2580,
#   'along': 2159,
#   'try': 1298,
#   'top': 2376,
#   'either': 2003,
#   'short': 2804,
#   'read': 906,
#   'low': 816,
#   'wrong': 1234,
#   'use': 1920,
#   'until': 248,
#   'friends': 1589,
#   'camera': 3283,
#   'kids': 1300,
#   'given': 1763,
#   'couple': 269,
#   'next': 502,
#   'need': 1057,
#   'start': 2186,
#   'enjoy': 1005,
#   'full': 446,
#   'classic': 2880,
#   'production': 2884,
#   'rest': 1271,
#   'truly': 709,
#   'perhaps': 2058,
#   'stupid': 545,
#   'awful': 2873,
#   'school': 2061,
#   'moments': 1025,
#   'video': 1045,
#   'mother': 1394,
#   'tell': 1198,
#   'mean': 954,
#   'getting': 1552,
#   'face': 239,
#   'keep': 2393,
#   'came': 1988,
#   'won': 76,
#   'understand': 865,
#   'small': 1272,
#   'terrible': 2873,
#   'others': 1256,
#   'recommend': 1196,
#   'name': 886,
#   'style': 576,
#   'playing': 2384,
#   'itself': 2144,
#   'boy': 449,
#   'wonderful': 1777,
#   'doing': 2075,
#   'stars': 3051,
#   'remember': 1649,
#   'person': 1547,
#   'definitely': 1871,
#   'gives': 3173,
#   'often': 1421,
#   'lost': 3163,
#   'dialogue': 196,
#   'written': 1559,
#   'live': 904,
#   'early': 1710,
#   'lines': 196,
#   'perfect': 1777,
#   'human': 394,
#   'case': 2016,
#   'entertaining': 736,
#   'head': 758,
#   'yes': 1994,
#   'title': 851,
#   'become': 2419,
#   'went': 1988,
#   'couldn': 76,
#   'hope': 1287,
#   'episode': 147,
#   'children': 1300,
#   'liked': 199,
#   'friend': 1589,
#   'certainly': 1871,
#   'based': 702,
#   'supposed': 2264,
#   'picture': 1185,
#   'piece': 2776,
#   'problem': 627,
#   'finally': 2592,
#   'against': 1915,
#   'absolutely': 1646,
#   'oh': 170,
#   'drama': 398,
#   'fans': 32,
#   'sort': 532,
#   'several': 305,
#   'overall': 970,
#   'cinema': 376,
#   'entire': 665,
#   'felt': 1851,
#   'under': 2029,
#   'son': 1394,
#   'worse': 1126,
#   'laugh': 1828,
#   'called': 573,
#   'evil': 339,
#   'direction': 208,
#   'lives': 1125,
#   'waste': 1151,
#   'killer': 2687,
#   'lead': 1841,
#   'humor': 1229,
#   'guys': 1669,
#   'care': 1861,
#   'beginning': 2451,
#   'white': 1611,
#   'dark': 1156,
#   'game': 3252,
#   'despite': 1743,
#   'seemed': 220,
#   'final': 1267,
#   'b': 495,
#   'becomes': 1552,
#   'wanted': 626,
#   'unfortunately': 204,
#   'mr': 1451,
#   'throughout': 1178,
#   'loved': 199,
#   'totally': 827,
#   'history': 3210,
#   'already': 3286,
#   'genre': 2726,
#   'turn': 2503,
#   'town': 2897,
#   'guess': 954,
#   'fine': 1777,
#   'able': 314,
#   'days': 1418,
#   'heart': 2914,
#   'city': 2959,
#   'flick': 1185,
#   'act': 69,
#   'run': 1483,
#   'side': 2882,
#   'wants': 508,
#   'quality': 1534,
#   'today': 512,
#   'tries': 2478,
#   'child': 3121,
#   'hand': 2902,
#   'sound': 2947,
#   'close': 1066,
#   'kill': 2671,
#   'horrible': 2873,
#   'past': 3197,
#   'example': 2347,
#   'starts': 1905,
#   'writing': 3047,
#   'viewer': 1604,
#   'turns': 2503,
#   'themselves': 1899,
#   'amazing': 2609,
#   'enjoyed': 199,
#   'etc': 2633,
#   'car': 1498,
#   'parts': 1025,
#   'behind': 925,
#   'directed': 950,
#   'works': 317,
#   'expect': 3012,
#   'michael': 1451,
#   'killed': 730,
#   'matter': 105,
#   'daughter': 538,
#   'fight': 511,
#   'favorite': 669,
#   'soon': 1049,
#   'kid': 3121,
#   'self': 655,
#   'decent': 774,
#   'stuff': 2918,
#   'gave': 293,
#   'blood': 1054,
#   'sometimes': 1421,
#   'type': 532,
#   'actress': 1520,
#   'eyes': 843,
#   'thinking': 232,
#   'group': 1551,
#   'girls': 2267,
#   'art': 531,
#   'violence': 1346,
#   'obviously': 2346,
#   'brilliant': 267,
#   'stop': 2524,
#   'stories': 1859,
#   'late': 1710,
#   'hour': 444,
#   'known': 1854,
#   'myself': 1086,
#   'except': 3054,
#   'writer': 1982,
#   'happened': 2139,
#   'hero': 2657,
#   'god': 1689,
#   'says': 1361,
#   'feeling': 586,
#   'highly': 983,
#   'heard': 124,
#   'coming': 1988,
#   'roles': 623,
#   'extremely': 2315,
#   'police': 1669,
#   'took': 3017,
#   'happens': 1684,
#   'slow': 310,
#   'leave': 1962,
#   'experience': 1848,
#   'moment': 1491,
#   'husband': 538,
#   'anyway': 3082,
#   'voice': 418,
#   'hell': 675,
#   'wouldn': 76,
#   'murder': 1307,
#   'attempt': 1169,
#   'involved': 681,
#   'age': 2079,
#   'obvious': 392,
#   'living': 3171,
#   'interest': 2457,
#   'including': 516,
#   'score': 1524,
#   'strong': 1302,
#   'looked': 410,
#   'taken': 3017,
#   'told': 1778,
#   'david': 1451,
#   'save': 1176,
#   'brother': 1394,
#   'ok': 87,
#   'wonder': 1079,
#   'none': 2801,
#   'happen': 2134,
#   'cut': 486,
#   'hours': 444,
#   'career': 525,
#   'please': 1006,
#   'cool': 1026,
#   'robert': 808,
#   'chance': 731,
#   'particularly': 709,
#   'gore': 863,
#   'james': 808,
#   'cannot': 496,
#   'simple': 1074,
#   'hit': 2483,
#   'across': 615,
#   'ago': 739,
#   'complete': 845,
#   'exactly': 1596,
#   'lack': 876,
#   'hilarious': 2124,
#   'crap': 338,
#   'o': 523,
#   'annoying': 1602,
#   'possible': 1795,
#   'alone': 1849,
#   'power': 2551,
#   'relationship': 1168,
#   'light': 1813,
#   'serious': 3155,
#   'sad': 1617,
#   'level': 1771,
#   'important': 543,
#   'running': 668,
#   'documentary': 1185,
#   'seriously': 493,
#   'usually': 612,
#   'whose': 1450,
#   'female': 2561,
#   'reality': 394,
#   'ends': 1508,
#   'scary': 863,
#   'somewhat': 2084,
#   'order': 1177,
#   'talent': 1978,
#   'happy': 1514,
#   'finds': 1179,
#   'taking': 3017,
#   'song': 172,
#   'number': 269,
#   'middle': 2390,
#   'shown': 1344,
#   'ridiculous': 206,
#   'room': 2496,
#   'strange': 385,
#   'change': 1492,
#   'call': 422,
#   'basically': 1772,
#   'released': 2438,
#   'usual': 1600,
#   'body': 896,
#   'opening': 948,
#   'jokes': 884,
#   'turned': 2503,
#   'mostly': 465,
#   'english': 439,
#   'country': 1072,
#   'wish': 1462,
#   'yourself': 955,
#   'apparently': 1073,
#   'cinematography': 208,
#   'opinion': 2587,
#   'silly': 1720,
#   'novel': 1435,
#   'attention': 1910,
#   'view': 2361,
#   'four': 2905,
#   'started': 801,
#   'word': 851,
#   'saying': 1793,
#   'jack': 915,
#   'disappointed': 1514,
#   'miss': 152,
#   'sequel': 988,
#   'single': 259,
#   'talking': 1800,
#   'huge': 859,
#   'thriller': 398,
#   'future': 3197,
#   'clich': 1401,
#   'shots': 1025,
#   'words': 851,
#   'major': 2270,
#   'cheap': 1754,
#   'straight': 1007,
#   'non': 2327,
#   'clearly': 2346,
#   'rating': 48,
#   'modern': 3206,
#   'beyond': 1548,
#   'knows': 82,
#   'knew': 1880,
#   'ones': 2211,
#   'due': 1728,
#   'fast': 310,
#   'problems': 372,
#   'events': 136,
#   'british': 985,
#   'sets': 1456,
#   'king': 2848,
#   'talk': 409,
#   'tells': 1778,
#   'comic': 2455,
#   'french': 439,
#   'parents': 1102,
#   'bring': 600,
#   'die': 904,
#   'easily': 1787,
#   'aren': 367,
#   'entertainment': 1478,
#   'local': 195,
#   'earth': 1502,
#   'add': 278,
#   'class': 956,
#   'sequence': 1491,
#   'upon': 1143,
#   'george': 808,
#   'above': 679,
#   'musical': 1213,
#   'television': 127,
#   'within': 3046,
#   'giving': 293,
#   'falls': 1251,
#   'similar': 658,
#   'york': 272,
#   'storyline': 463,
#   'ten': 947,
#   'supporting': 548,
#   'clear': 392,
#   'mystery': 2999,
#   'haven': 1044,
#   'easy': 975,
#   'appears': 220,
#   'hate': 2929,
#   'romantic': 1159,
#   'five': 947,
#   'predictable': 1401,
#   'review': 2140,
#   'near': 1150,
#   'typical': 108,
#   'lots': 446,
#   'ways': 1042,
#   'bunch': 1551,
#   'team': 2031,
#   'enjoyable': 736,
#   'begins': 1905,
#   'named': 491,
#   'dialog': 196,
#   'general': 3143,
#   'stand': 589,
#   'crime': 219,
#   'working': 3171,
#   'elements': 222,
#   'mention': 278,
#   'eye': 3001,
#   'message': 25,
#   'e': 2568,
#   'theme': 682,
#   'filmed': 1010,
#   'richard': 808,
#   'episodes': 147,
#   'points': 1949,
#   'certain': 524,
#   'avoid': 2945,
#   'songs': 172,
#   'red': 807,
#   'america': 178,
#   'sorry': 1565,
#   'tale': 860,
#   'whether': 2003,
#   'gay': 1091,
#   'release': 475,
#   'dull': 1120,
#   'surprised': 773,
#   'moving': 1039,
#   'among': 2970,
#   'tom': 746,
#   'th': 247,
#   'viewers': 1604,
#   'stay': 1962,
#   'de': 1127,
#   'using': 1920,
#   'minute': 444,
#   'needs': 508,
#   'fall': 1251,
#   'effort': 1169,
#   'feels': 2782,
#   'gone': 811,
#   'space': 2262,
#   'lee': 641,
#   'leads': 963,
#   'kept': 2393,
#   'paul': 1451,
#   'nearly': 2271,
#   'theater': 242,
#   'tried': 1298,
#   'herself': 2422,
#   'comments': 277,
#   'means': 1363,
#   'peter': 1451,
#   'period': 1245,
#   'showing': 1624,
#   'third': 957,
#   'truth': 2243,
#   'sister': 538,
#   'brought': 600,
#   'suspense': 1664,
#   'buy': 622,
#   'doubt': 2119,
#   'soundtrack': 1524,
#   'lady': 1547,
#   'somehow': 1512,
#   'killing': 1628,
#   'feature': 674,
#   'follow': 14,
#   'sequences': 1025,
#   'viewing': 613,
#   'fantastic': 1777,
#   'editing': 862,
#   'form': 2957,
#   'famous': 1783,
#   'material': 1998,
#   'realistic': 2097,
#   'rent': 670,
#   'average': 1599,
#   'cop': 10,
#   'okay': 87,
#   'dog': 1530,
#   'check': 1165,
#   'whatever': 190,
#   'monster': 732,
#   'rock': 2844,
#   'reviews': 277,
#   'imagine': 1674,
#   'move': 837,
#   'figure': 1165,
#   'oscar': 1135,
#   'surprise': 1419,
#   'forget': 1198,
#   'lame': 545,
#   'premise': 1214,
#   'believable': 814,
#   'fi': 1643,
#   'weak': 545,
#   'indeed': 2745,
#   'animation': 1412,
#   'deal': 1104,
#   'poorly': 1096,
#   'sci': 2697,
#   'free': 1400,
#   'possibly': 1787,
#   'actual': 2088,
#   'expected': 826,
#   'learn': 2723,
#   'hear': 2645,
#   'eventually': 2592,
#   'dr': 1034,
#   'stage': 1180,
#   'forced': 314,
#   'sexual': 1853,
#   'note': 2834,
#   'atmosphere': 1173,
#   'deep': 1431,
#   'society': 429,
#   'greatest': 365,
#   'sit': 404,
#   'otherwise': 3037,
#   'open': 3110,
#   'wait': 1863,
#   'leaves': 1041,
#   'difficult': 975,
#   'question': 353,
#   'romance': 1159,
#   'decided': 626,
#   'screenplay': 3047,
#   'begin': 2186,
#   'reading': 906,
#   'plus': 1908,
#   'joe': 2845,
#   'situation': 729,
#   'western': 236,
#   'became': 2578,
#   'subject': 682,
#   'particular': 1084,
#   'earlier': 1048,
#   'hot': 406,
#   'nor': 1253,
#   'male': 2561,
#   'towards': 3109,
#   'box': 2460,
#   'gun': 1055,
#   'crew': 2180,
#   'brothers': 1163,
#   'interested': 1365,
#   'personal': 2086,
#   'acted': 1559,
#   'street': 255,
#   'meet': 387,
#   'credits': 2944,
#   'previous': 1048,
#   'cheesy': 1720,
#   'imdb': 1262,
#   'footage': 959,
#   'business': 2619,
#   'powerful': 252,
#   'memorable': 447,
#   'worked': 811,
#   'battle': 511,
#   'shame': 1134,
#   'writers': 2622,
#   'mess': 2776,
#   'effect': 2308,
#   'laughs': 1591,
#   'season': 147,
#   'whom': 1450,
#   'features': 402,
#   'result': 2895,
#   'dramatic': 939,
#   'older': 1138,
#   'air': 2180,
#   'setting': 1456,
#   'perfectly': 65,
#   'unless': 1014,
#   'era': 1245,
#   'quickly': 1049,
#   'needed': 1008,
#   'keeps': 2393,
#   'nature': 664,
#   'hands': 1396,
#   'boys': 2267,
#   'baby': 2556,
#   'bill': 746,
#   'crazy': 2019,
#   'badly': 604,
#   'total': 845,
#   'background': 1386,
#   'directing': 315,
#   'realize': 788,
#   'emotional': 1019,
#   'mark': 197,
#   'comment': 2140,
#   'forward': 647,
#   'present': 1951,
#   'japanese': 1487,
#   'appear': 1149,
#   'twist': 2479,
#   'development': 699,
#   'girlfriend': 7,
#   'pay': 800,
#   'telling': 1778,
#   'write': 3264,
#   'superb': 1777,
#   'rich': 1340,
#   'various': 305,
#   'meets': 491,
#   'c': 2568,
#   'unique': 1825,
#   'dance': 1718,
#   'weird': 385,
#   'island': 2897,
#   'william': 808,
#   'directors': 279,
#   'plenty': 446,
#   'secret': 1613,
#   'break': 2647,
#   'fighting': 2329,
#   'disney': 1047,
#   'front': 1265,
#   'apart': 2337,
#   'brings': 600,
#   'sounds': 410,
#   'masterpiece': 2880,
#   'doctor': 10,
#   'fairly': 2599,
#   'incredibly': 2315,
#   'villain': 2657,
#   'outside': 925,
#   'dream': 1667,
#   'married': 2815,
#   'missing': 2621,
#   'leading': 1841,
#   'party': 420,
#   'manages': 2478,
#   'return': 2458,
#   'beauty': 1320,
#   'remake': 1095,
#   'reasons': 1538,
#   'inside': 925,
#   'zombie': 1668,
#   'fantasy': 1934,
#   'list': 815,
#   'admit': 713,
#   'rate': 1819,
#   'ideas': 542,
#   'political': 986,
#   'create': 2128,
#   'ask': 422,
#   'creepy': 2634,
#   'meant': 2264,
#   'joke': 289,
#   'unlike': 1528,
#   'potential': 2779,
#   'cute': 1470,
#   'dumb': 545,
#   'success': 1076,
#   'copy': 1045,
#   'portrayed': 1490,
#   'nudity': 2581,
#   'fails': 2500,
#   ...},
#  16490)

# %%
#key, val = word_centroid_map.items()[2]
type(word_centroid_map)
# Out:
# dict

# %%
# For the first 10 clusters
for cluster in range(0,10):
    #
    # Print the cluster number  
    #print "\nCluster %d" #% cluster
    print(f"\nCluster {cluster}")
    #
    # Find all of the words for that cluster number, and print them out
    a_view = word_centroid_map.items()
    tuples = list(a_view)
    words = []
    for i in range(0,len(word_centroid_map.values())):
        if( tuples[i][1] == cluster ):
            words.append(tuples[i][0])
    print(words)
# Out:
# Cluster 0
# ['terribly', 'horribly', 'intentionally']
#
# Cluster 1
# ['mercilessly', 'hypnosis', 'injecting', 'indulges']
#
# Cluster 2
# ['base', 'fleet', 'bunker', 'nuke', 'arctic', 'formation', 'outpost']
#
# Cluster 3
# ['fonda', 'raymond', 'andrews', 'lionel', 'massey', 'ferrer', 'ably', 'marlowe', 'finney', 'goddard', 'brennan', 'hadley', 'robson', 'jacobi', 'pidgeon', 'denholm', 'dyan', 'scheider', 'macmahon', 'macgregor', 'paulette']
#
# Cluster 4
# ['grounded']
#
# Cluster 5
# ['identification']
#
# Cluster 6
# ['tools', 'barrier', 'codes']
#
# Cluster 7
# ['girlfriend', 'boyfriend', 'neighbor', 'gal', 'roommate', 'neighbour']
#
# Cluster 8
# ['eggs', 'easter']
#
# Cluster 9
# ['ouch']

# %%
def create_bag_of_centroids( wordlist, word_centroid_map ):
    #
    # The number of clusters is equal to the highest cluster index
    # in the word / centroid map
    num_centroids = max( word_centroid_map.values() ) + 1
    #
    # Pre-allocate the bag of centroids vector (for speed)
    bag_of_centroids = np.zeros( num_centroids, dtype="float32" )
    #
    # Loop over the words in the review. If the word is in the vocabulary,
    # find which cluster it belongs to, and increment that cluster count 
    # by one
    for word in wordlist:
        if word in word_centroid_map:
            index = word_centroid_map[word]
            bag_of_centroids[index] += 1
    #
    # Return the "bag of centroids"
    return bag_of_centroids

# %%
# Pre-allocate an array for the training set bags of centroids (for speed)
train_centroids = np.zeros( (train["review"].size, int(num_clusters)), \
    dtype="float32" )

# Transform the training set reviews into bags of centroids
counter = 0
for review in clean_train_reviews:
    train_centroids[counter] = create_bag_of_centroids( review, \
        word_centroid_map )
    counter += 1

# Repeat for test reviews 
test_centroids = np.zeros((test["review"].size, int(num_clusters)), \
    dtype="float32" )

counter = 0
for review in clean_test_reviews:
    test_centroids[counter] = create_bag_of_centroids( review, \
        word_centroid_map )
    counter += 1

# %%
# This cell take some minutes
# Fit a random forest and extract predictions 
forest = RandomForestClassifier(n_estimators = 100)

# Fitting the forest may take a few minutes
print("Fitting a random forest to labeled training data...")
forest = forest.fit(train_centroids,train["sentiment"])
result = forest.predict(test_centroids)

# Write the test results 
output = pd.DataFrame(data={"id":test["id"], "sentiment":result})
output.to_csv( "BagOfCentroids.csv", index=False, quoting=3 )
# Out:
# Fitting a random forest to labeled training data...
